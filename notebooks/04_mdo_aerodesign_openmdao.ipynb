# %% [markdown]
# # Módulo 4 — MDO inspirado em AeroDesign
#
# Demonstração futura de MDO simplificado com OpenMDAO.
#
# > Placeholder da Entrega 1. O notebook completo será desenvolvido na etapa de implementação dos exemplos computacionais.

# %%
print('Notebook placeholder — SEMUNI 2026')
